# %% [markdown]
# <a href="https://colab.research.google.com/github/sathishweb997/ai-mentor-portfolio-sathishlutukurthi/blob/main/Day2_lab1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Students starting programming from zero Need structured daily learning plan Focus on logic building and consistency

# %% [markdown]
# Beginner Programming Roadmap (Daily Plan)
# Phase 1: First 30 Days → Programming Basics
# Daily Time: 2 Hours
# Hour 1 → Concepts Learn
#
# Daily small topic:
#
# Day-wise flow:
#
# Variables
# Data Types
# Input/Output
# Conditions (if, else)
# Loops
# Functions
# Arrays
# Strings
# Basic Patterns
# Simple Logic Problems
#
# Language:
#
# C / C++ / Java / Python
# Placements ki C++ or Java better.
# Hour 2 → Practice
#
# Daily compulsory:
#
# 5 small programs
# Same day topic practice
#
# Example:
#
# If loops topic:
#
# 1 to 100 print
# Even numbers
# Sum of numbers
# Multiplication table
# Factorial
